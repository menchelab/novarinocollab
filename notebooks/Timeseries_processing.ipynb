# %%
# this takes approximately 200GB of RAM due to the count matrix being saved as dense array
import h5py
import anndata as ad
import pandas as pd
import numpy as np
import scanpy as sc
from scipy.sparse import coo_matrix, hstack, vstack, issparse

def read_brain_atlas_data(filename):
    h5 = h5py.File(filename, 'r')
    print('reading chunks')
    countdata = h5['data']['counts']
    nrows, ncols = countdata.shape
    sparsechunks, sparsecolchunks = [], []
    for rowslice, colslice in countdata.iter_chunks():
        sparsechunk = coo_matrix(
            countdata[rowslice, colslice].T.astype(np.int32),
        )
        sparsechunk.eliminate_zeros()
        sparsechunks.append(
            sparsechunk
        )
        
        if colslice.stop == ncols:
            sparsecolchunks.append(
                vstack(sparsechunks)
            )
            
            del sparsechunks
            sparsechunks = []
    
    print('stack column chunks')
    X = hstack(sparsecolchunks)
    del sparsecolchunks
    
    print('convert to csr matrix')
    X = X.tocsr()
    
    row_col = dict()
    for h5key, dictkey in zip(['gene', 'samples'], ['var', 'obs']):
        print(f'reading {h5key}')
        row_col[dictkey] = pd.DataFrame(
            index = np.char.decode(
                h5['data'][h5key][()],
                encoding = 'utf-8'
            )
        )
    
    print('converting to AnnData')
    return ad.AnnData(X, **row_col)

adata = read_brain_atlas_data('../data/mouse_brain_adult_counts.h5')
adata.obs.index = adata.obs.index.str.replace('10X_cells.', '', regex = True)
metadata = pd.read_csv(
    '../data/mouse_brain_adult_anno.csv',
    index_col = 0
)
metadata.index = metadata.sample_name.str.replace('10X_cells.', '', regex = True).to_list()
metadata.drop(
    columns = [
        'sample_name',
        'exp_component_name'
    ]
)
adata.obs = adata.obs.merge(
    metadata,
    left_index = True,
    right_index = True,
    how = 'left'
)
adata.write_h5ad('../data/mouse_brain_adult.h5ad')
# Out:
# reading chunks
# stack column chunks and convert to csr matrix
# reading gene
# reading samples
# converting to AnnData
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'sex_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'region_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'library_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'platform_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'joint_region_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'joint_region_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'region_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'sex_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'platform_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tasic18_cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tasic18_cluster_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tasic18_subclass_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tasic18_subclass_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tasic18_class_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tasic18_class_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'Miniatlas_cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'Miniatlas_cluster_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'genes_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'ref.cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'old.cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cluster_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'supertype_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'supertype_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'subclass_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'subclass_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'neighborhood_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'neighborhood_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'class_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'class_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'ss_cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tenx_cluster_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tenx_cluster_label' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_type_accession_color' as categorical
# /users/daniel.malzl/.conda/envs/nova/lib/python3.9/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'cell_type_accession_label' as categorical

# %%
# only using primary somatosensory cortex (SSp)
adult = adata[adata.obs.region_label == 'SSp', :].copy()

# %%
p4 = sc.read_10x_h5('../data/mouse_brain_P4.h5')
e14_5 = sc.read_10x_h5('../data/mouse_brain_E14_5.h5')
metadata = pd.read_csv(
    '../data/metaData_scDevSC.txt',
    sep = '\t',
    skiprows = [1]
)
metadata.index = metadata.NAME.to_list()
metadata.drop(
    columns = ['NAME'],
    inplace = True
)
metadata
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#                           orig_ident  nCount_RNA  nFeature_RNA  percent_mito  \
# E10_v1_AAACCTGAGGGTCTCC-1        E10        1544          1022      0.020078
# E10_v1_AAACCTGCACAACGCC-1        E10        1157           783      0.014693
# E10_v1_AAACCTGCACGACGAA-1        E10        2081          1200      0.016338
# E10_v1_AAACCTGCAGACAAGC-1        E10        2490          1430      0.021285
# E10_v1_AAACCTGCAGAGCCAA-1        E10        2514          1416      0.021082
# ...                              ...         ...           ...           ...
# P4_TTTGTCAGTTGATTGC-1             P4        8028          3130      0.064275
# P4_TTTGTCATCAACGGCC-1             P4       15768          4425      0.041540
# P4_TTTGTCATCCGTTGTC-1             P4       21692          4931      0.041398
# P4_TTTGTCATCGATGAGG-1             P4        3680          1897      0.057880
# P4_TTTGTCATCTTTCCTC-1             P4        6641          2667      0.024394
#
#                            n_hkgene   S_Score  G2M_Score Phase  CC_Difference  \
# E10_v1_AAACCTGAGGGTCTCC-1        51  0.356987   0.330795     S       0.026192
# E10_v1_AAACCTGCACAACGCC-1        39  0.453854   0.260560     S       0.193294
# E10_v1_AAACCTGCACGACGAA-1        67  0.447598   0.218746     S       0.228852
# E10_v1_AAACCTGCAGACAAGC-1        71  0.227723   0.307102   G2M      -0.079379
# E10_v1_AAACCTGCAGAGCCAA-1        70  0.738406   0.136556     S       0.601850
# ...                             ...       ...        ...   ...            ...
# P4_TTTGTCAGTTGATTGC-1            74 -0.225020  -0.244369    G1       0.019349
# P4_TTTGTCATCAACGGCC-1            79 -0.219746  -0.236435    G1       0.016689
# P4_TTTGTCATCCGTTGTC-1            76 -0.207196  -0.244800    G1       0.037604
# P4_TTTGTCATCGATGAGG-1            67 -0.185044  -0.185335    G1       0.000291
# P4_TTTGTCATCTTTCCTC-1            75 -0.141394  -0.225909    G1       0.084515
#
#                            seurat_clusters  ...   donor_id          species  \
# E10_v1_AAACCTGAGGGTCTCC-1               34  ...  mouse_E10  NCBITaxon_10090
# E10_v1_AAACCTGCACAACGCC-1               34  ...  mouse_E10  NCBITaxon_10090
# E10_v1_AAACCTGCACGACGAA-1               34  ...  mouse_E10  NCBITaxon_10090
# E10_v1_AAACCTGCAGACAAGC-1               37  ...  mouse_E10  NCBITaxon_10090
# E10_v1_AAACCTGCAGAGCCAA-1               37  ...  mouse_E10  NCBITaxon_10090
# ...                                    ...  ...        ...              ...
# P4_TTTGTCAGTTGATTGC-1                   16  ...   mouse_P4  NCBITaxon_10090
# P4_TTTGTCATCAACGGCC-1                   24  ...   mouse_P4  NCBITaxon_10090
# P4_TTTGTCATCCGTTGTC-1                   16  ...   mouse_P4  NCBITaxon_10090
# P4_TTTGTCATCGATGAGG-1                   16  ...   mouse_P4  NCBITaxon_10090
# P4_TTTGTCATCTTTCCTC-1                   12  ...   mouse_P4  NCBITaxon_10090
#
#                                 disease disease__ontology_label  \
# E10_v1_AAACCTGAGGGTCTCC-1  PATO_0000461                  normal
# E10_v1_AAACCTGCACAACGCC-1  PATO_0000461                  normal
# E10_v1_AAACCTGCACGACGAA-1  PATO_0000461                  normal
# E10_v1_AAACCTGCAGACAAGC-1  PATO_0000461                  normal
# E10_v1_AAACCTGCAGAGCCAA-1  PATO_0000461                  normal
# ...                                 ...                     ...
# P4_TTTGTCAGTTGATTGC-1      PATO_0000461                  normal
# P4_TTTGTCATCAACGGCC-1      PATO_0000461                  normal
# P4_TTTGTCATCCGTTGTC-1      PATO_0000461                  normal
# P4_TTTGTCATCGATGAGG-1      PATO_0000461                  normal
# P4_TTTGTCATCTTTCCTC-1      PATO_0000461                  normal
#
#                                     organ organ__ontology_label  \
# E10_v1_AAACCTGAGGGTCTCC-1  UBERON_0008930  somatosensory cortex
# E10_v1_AAACCTGCACAACGCC-1  UBERON_0008930  somatosensory cortex
# E10_v1_AAACCTGCACGACGAA-1  UBERON_0008930  somatosensory cortex
# E10_v1_AAACCTGCAGACAAGC-1  UBERON_0008930  somatosensory cortex
# E10_v1_AAACCTGCAGAGCCAA-1  UBERON_0008930  somatosensory cortex
# ...                                   ...                   ...
# P4_TTTGTCAGTTGATTGC-1      UBERON_0008930  somatosensory cortex
# P4_TTTGTCATCAACGGCC-1      UBERON_0008930  somatosensory cortex
# P4_TTTGTCATCCGTTGTC-1      UBERON_0008930  somatosensory cortex
# P4_TTTGTCATCGATGAGG-1      UBERON_0008930  somatosensory cortex
# P4_TTTGTCATCTTTCCTC-1      UBERON_0008930  somatosensory cortex
#
#                           library_preparation_protocol  \
# E10_v1_AAACCTGAGGGTCTCC-1                  EFO_0009899
# E10_v1_AAACCTGCACAACGCC-1                  EFO_0009899
# E10_v1_AAACCTGCACGACGAA-1                  EFO_0009899
# E10_v1_AAACCTGCAGACAAGC-1                  EFO_0009899
# E10_v1_AAACCTGCAGAGCCAA-1                  EFO_0009899
# ...                                                ...
# P4_TTTGTCAGTTGATTGC-1                      EFO_0009899
# P4_TTTGTCATCAACGGCC-1                      EFO_0009899
# P4_TTTGTCATCCGTTGTC-1                      EFO_0009899
# P4_TTTGTCATCGATGAGG-1                      EFO_0009899
# P4_TTTGTCATCTTTCCTC-1                      EFO_0009899
#
#                           library_preparation_protocol__ontology_label    sex  \
# E10_v1_AAACCTGAGGGTCTCC-1                         10X 3' v2 sequencing  mixed
# E10_v1_AAACCTGCACAACGCC-1                         10X 3' v2 sequencing  mixed
# E10_v1_AAACCTGCACGACGAA-1                         10X 3' v2 sequencing  mixed
# E10_v1_AAACCTGCAGACAAGC-1                         10X 3' v2 sequencing  mixed
# E10_v1_AAACCTGCAGAGCCAA-1                         10X 3' v2 sequencing  mixed
# ...                                                                ...    ...
# P4_TTTGTCAGTTGATTGC-1                             10X 3' v2 sequencing  mixed
# P4_TTTGTCATCAACGGCC-1                             10X 3' v2 sequencing  mixed
# P4_TTTGTCATCCGTTGTC-1                             10X 3' v2 sequencing  mixed
# P4_TTTGTCATCGATGAGG-1                             10X 3' v2 sequencing  mixed
# P4_TTTGTCATCTTTCCTC-1                             10X 3' v2 sequencing  mixed
#
#                           species__ontology_label
# E10_v1_AAACCTGAGGGTCTCC-1            Mus musculus
# E10_v1_AAACCTGCACAACGCC-1            Mus musculus
# E10_v1_AAACCTGCACGACGAA-1            Mus musculus
# E10_v1_AAACCTGCAGACAAGC-1            Mus musculus
# E10_v1_AAACCTGCAGAGCCAA-1            Mus musculus
# ...                                           ...
# P4_TTTGTCAGTTGATTGC-1                Mus musculus
# P4_TTTGTCATCAACGGCC-1                Mus musculus
# P4_TTTGTCATCCGTTGTC-1                Mus musculus
# P4_TTTGTCATCGATGAGG-1                Mus musculus
# P4_TTTGTCATCTTTCCTC-1                Mus musculus
#
# [98047 rows x 27 columns]
